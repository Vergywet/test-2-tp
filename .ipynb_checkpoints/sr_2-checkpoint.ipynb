# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data = pd.read_csv("C:/Users/User/OneDrive/Desktop/Informal_Settlement_Programme_-1898186875815614491.csv")

# %%
print(data)
# Out:
#      OBJECTID     NAME_OF_SE       ALT_NAME  \
# 0           1       Amatikwe
# 1           2  Congo Phase 2  Congo Phase 2
# 2           3  Africa Inanda         Africa
# 3           4        Namibia
# 4           5     Mshayazafe
# ..        ...            ...            ...
# 561       562  Mandela Drive
# 562       563      Ezipokini
# 563       564       Kingrest
# 564       565    Duma Mbhele
# 565       566         Soweto
#
#                                  STREETNAME  WARD_S  \
# 0                                MR93 North  56/108
# 1                          MR93 /MR93 North   55/57
# 2                    Curnick Ndlovu Highway      55
# 3    Curnick Ndlovu Highway / Matshana Road  108/44
# 4                              Sidudla Road      55
# ..                                      ...     ...
# 561                          Horseshoe Road      32
# 562                             Sirdar road      32
# 563                          Lucas Crescent      66
# ...

# %%
print(data.head(5))
# Out:
#    OBJECTID     NAME_OF_SE       ALT_NAME  \
# 0         1       Amatikwe
# 1         2  Congo Phase 2  Congo Phase 2
# 2         3  Africa Inanda         Africa
# 3         4        Namibia
# 4         5     Mshayazafe
#
#                                STREETNAME  WARD_S  \
# 0                              MR93 North  56/108
# 1                        MR93 /MR93 North   55/57
# 2                  Curnick Ndlovu Highway      55
# 3  Curnick Ndlovu Highway / Matshana Road  108/44
# 4                            Sidudla Road      55
#
#                       PLANNING_U           LATITUDE         LONGITUDE  \
# 0                       Amatikwe  -29,6847594568261  30,9331993743659
# 1                   Inanda Congo  -29,6930565996813  30,9524428875002
# 2        Ohlange-Africa / Stop 8   -29,700492743755  30,9486579023242
# 3                 Inanda Namibia   -29,703771886581  30,9335017254606
# 4  Mshayazafe / Ohlange - Africa  -29,7066784039778  30,9469610275001
#
# ...

# %%
print(data.tail(4))
# Out:
#      OBJECTID   NAME_OF_SE ALT_NAME                           STREETNAME  \
# 562       563    Ezipokini                                   Sirdar road
# 563       564     Kingrest                                Lucas Crescent
# 564       565  Duma Mbhele                                  Mbele Street
# 565       566       Soweto           Thirty Third Avenue / Clermont Road
#
#     WARD_S             PLANNING_U           LATITUDE         LONGITUDE  \
# 562     32              Clairwood  -29,9114172952167  30,9823241207283
# 563     66  Fynnlands / Grosvenor  -29,9068386243348  31,0114634124573
# 564     69            Lamontville  -29,9385857741353  30,9381937971102
# 565     92       Clermont Emngeni  -29,7954645668291  30,9075593857641
#
#        REGION                           WATER_SUPP         SANITATION  \
# 562  Southern                                  TBC                TBC
# 563  Southern                                  TBC                TBC
# ...

# %%
print(data.dtypes)
# Out:
# OBJECTID           int64
# NAME_OF_SE        object
# ALT_NAME          object
# STREETNAME        object
# WARD_S            object
# PLANNING_U        object
# LATITUDE          object
# LONGITUDE         object
# REGION            object
# WATER_SUPP        object
# SANITATION        object
# REFUSE            object
# ELECTRIC_2        object
# UNIREFCODE        object
# EST_HHC            int64
# NUSP_CAT          object
# Shape__Area      float64
# Shape__Length    float64
# dtype: object

# %%
data.fillna(0, inplace=True)  # Fill with 0
#data.fillna(data.mean(), inplace=True)  # Fill with the mean of each column
#data.fillna(method='ffill', inplace=True)
#data.fillna(method='bfill', inplace=True)
data.dropna(inplace=True)  # Drop rows with any missing values
data.dropna(axis=1, inplace=True)  # Drop columns with any missing values
#data.interpolate(inplace=True)
print(data.isnull().sum())
# Out:
# OBJECTID         0
# NAME_OF_SE       0
# ALT_NAME         0
# STREETNAME       0
# WARD_S           0
# PLANNING_U       0
# LATITUDE         0
# LONGITUDE        0
# REGION           0
# WATER_SUPP       0
# SANITATION       0
# REFUSE           0
# ELECTRIC_2       0
# UNIREFCODE       0
# EST_HHC          0
# NUSP_CAT         0
# Shape__Area      0
# Shape__Length    0
# dtype: int64

# %%
duplicates = data.duplicated().sum()

# %%
print(data.columns)
# Out:
# Index(['OBJECTID', 'NAME_OF_SE', 'ALT_NAME', 'STREETNAME', 'WARD_S',
#        'PLANNING_U', 'LATITUDE', 'LONGITUDE', 'REGION', 'WATER_SUPP',
#        'SANITATION', 'REFUSE', 'ELECTRIC_2', 'UNIREFCODE', 'EST_HHC',
#        'NUSP_CAT', 'Shape__Area', 'Shape__Length'],
#       dtype='object')

# %%
print(data.size)
# Out:
# 10188

# %%
print(data.shape)
# Out:
# (566, 18)

# %%
sliced_data = data.iloc[:1, 5:]

# Display the sliced data
print('slided values are : ',sliced_data)
# Out:
# slided values are :    PLANNING_U           LATITUDE         LONGITUDE    REGION  WATER_SUPP  \
# 0   Amatikwe  -29,6847594568261  30,9331993743659  Northern  Standpipes
#
#     SANITATION           REFUSE ELECTRIC_2 UNIREFCODE  EST_HHC NUSP_CAT  \
# 0  Pit Privies  C&SW contractor        Yes      I0005     3250       B1
#
#     Shape__Area  Shape__Length
# 0  2.393433e+06   22801.689196

# %%
est_hhc = [0,1,2,3,4,5,6]
objectid = [3239,3236,3239,32348,3239,3221,3222]

plt.scatter(est_hhc,objectid)
plt.title('Scatter plot showing relationship between EST_HHC vs OBJECTID')
plt.xlabel('EST_HHC')
plt.ylabel('OBJECTID')
plt.show()

# %%
output = data.head(12) 

plt.figure(figsize=(12, 6))
sns.barplot(x='NAME_OF_SE', y='EST_HHC',  data=output)
plt.title('The estimated household per stree name')
plt.xlabel('The street names')
plt.ylabel('Estimated household count per street')
plt.xticks(rotation=45)
plt.show()

# %%
hold = data.nlargest(8,'OBJECTID')

name = hold['NAME_OF_SE']
output = hold['OBJECTID']

plt.figure(figsize = (10,8))
plt.pie(output,labels = name,autopct= '%1.1f%%',startangle=140)
plt.title('Pie chart for Name OF SE and Objectid')
plt.show()

# %%
data =  np.random.normal(loc=20.0,scale=5.0,size = 365)
plt.hist(data,bins=20,color = "Purple",alpha= 0.7)
plt.title('Histograph of  EST_HHC vs OBJECTID')
plt.xlabel('EST_HHC')
plt.ylabel('OBJECTID')
plt.show()

# %%
est_hhc = [0,1,2,3,4,5,6]

sns.kdeplot(est_hhc,shade=True)
plt.title('A kde graph for Clean sheets')
plt.xlabel('EST_HHC')
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_12968\644785594.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(est_hhc,shade=True)
